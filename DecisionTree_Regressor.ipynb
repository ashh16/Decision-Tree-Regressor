# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)

# %%
taxi_df=pd.read_csv(r'TaxiFare.csv',header=0,index_col=0)
print(taxi_df.shape)
# Out:
# (50000, 7)

# %%
taxi_df.head()
# Out:
#            amount      date_time_of_pickup  longitude_of_pickup  \
# unique_id
# 26:21.0       4.5  2009-06-15 17:26:21 UTC           -73.844311
# 52:16.0      16.9  2010-01-05 16:52:16 UTC           -74.016048
# 35:00.0       5.7  2011-08-18 00:35:00 UTC           -73.982738
# 30:42.0       7.7  2012-04-21 04:30:42 UTC           -73.987130
# 51:00.0       5.3  2010-03-09 07:51:00 UTC           -73.968095
#
#            latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# unique_id
# 26:21.0             40.721319            -73.841610            40.712278
# 52:16.0             40.711303            -73.979268            40.782004
# 35:00.0             40.761270            -73.991242            40.750562
# 30:42.0             40.733143            -73.991567            40.758092
# 51:00.0             40.768008            -73.956655            40.783762
#
#            no_of_passenger
# unique_id
# 26:21.0                  1
# 52:16.0                  1
# ...

# %%
taxi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 26:21.0 to 13:14.0
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   amount                50000 non-null  float64
#  1   date_time_of_pickup   50000 non-null  object
#  2   longitude_of_pickup   50000 non-null  float64
#  3   latitude_of_pickup    50000 non-null  float64
#  4   longitude_of_dropoff  50000 non-null  float64
#  5   latitude_of_dropoff   50000 non-null  float64
#  6   no_of_passenger       50000 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.1+ MB

# %%
taxi_df.date_time_of_pickup=pd.to_datetime(taxi_df.date_time_of_pickup)

# %%
taxi_df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  50000.000000         50000.000000        50000.000000
# mean      11.364171           -72.509756           39.933759
# std        9.685557            10.393860            6.224857
# min       -5.000000           -75.423848          -74.006893
# 25%        6.000000           -73.992062           40.734880
# 50%        8.500000           -73.981840           40.752678
# 75%       12.500000           -73.967148           40.767360
# max      200.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# count          50000.000000         50000.000000     50000.000000
# mean             -72.504616            39.926251         1.667840
# std               10.407570             6.014737         1.289195
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991152            40.734372         1.000000
# ...

# %%
taxi_df.head()
# Out:
#            amount       date_time_of_pickup  longitude_of_pickup  \
# unique_id
# 26:21.0       4.5 2009-06-15 17:26:21+00:00           -73.844311
# 52:16.0      16.9 2010-01-05 16:52:16+00:00           -74.016048
# 35:00.0       5.7 2011-08-18 00:35:00+00:00           -73.982738
# 30:42.0       7.7 2012-04-21 04:30:42+00:00           -73.987130
# 51:00.0       5.3 2010-03-09 07:51:00+00:00           -73.968095
#
#            latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# unique_id
# 26:21.0             40.721319            -73.841610            40.712278
# 52:16.0             40.711303            -73.979268            40.782004
# 35:00.0             40.761270            -73.991242            40.750562
# 30:42.0             40.733143            -73.991567            40.758092
# 51:00.0             40.768008            -73.956655            40.783762
#
#            no_of_passenger
# unique_id
# 26:21.0                  1
# 52:16.0                  1
# ...

# %%
taxi_df=taxi_df.assign(hour=taxi_df.date_time_of_pickup.dt.hour,
                       day=taxi_df.date_time_of_pickup.dt.day,
                       month=taxi_df.date_time_of_pickup.dt.month,
                       year=taxi_df.date_time_of_pickup.dt.year,
                       dayofweek=taxi_df.date_time_of_pickup.dt.day_of_week)

# %%
taxi_df.head()
# Out:
#            amount       date_time_of_pickup  longitude_of_pickup  \
# unique_id
# 26:21.0       4.5 2009-06-15 17:26:21+00:00           -73.844311
# 52:16.0      16.9 2010-01-05 16:52:16+00:00           -74.016048
# 35:00.0       5.7 2011-08-18 00:35:00+00:00           -73.982738
# 30:42.0       7.7 2012-04-21 04:30:42+00:00           -73.987130
# 51:00.0       5.3 2010-03-09 07:51:00+00:00           -73.968095
#
#            latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# unique_id
# 26:21.0             40.721319            -73.841610            40.712278
# 52:16.0             40.711303            -73.979268            40.782004
# 35:00.0             40.761270            -73.991242            40.750562
# 30:42.0             40.733143            -73.991567            40.758092
# 51:00.0             40.768008            -73.956655            40.783762
#
#            no_of_passenger  hour  day  month  year  dayofweek
# unique_id
# ...

# %%
taxi_df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  50000.000000         50000.000000        50000.000000
# mean      11.364171           -72.509756           39.933759
# std        9.685557            10.393860            6.224857
# min       -5.000000           -75.423848          -74.006893
# 25%        6.000000           -73.992062           40.734880
# 50%        8.500000           -73.981840           40.752678
# 75%       12.500000           -73.967148           40.767360
# max      200.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger  \
# count          50000.000000         50000.000000     50000.000000
# mean             -72.504616            39.926251         1.667840
# std               10.407570             6.014737         1.289195
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991152            40.734372         1.000000
# ...

# %%
taxi_df.drop("date_time_of_pickup",axis=1,inplace=True)

# %%
taxi_df.latitude_of_pickup.value_counts().index.sort_values(ascending=True)
# Out:
# Float64Index([-74.006893,  -74.00621, -74.004027,    -73.995, -73.992947,
#                -73.99184, -73.988467, -73.987585, -73.987307, -73.986968,
#               ...
#                 41.03249,  41.035688,  41.150487,  41.366138,  41.391042,
#                41.523217,      41.65,  42.160275,  43.098708, 401.083332],
#              dtype='float64', length=36594)

# %%
taxi_df.latitude_of_pickup.replace(401.083332,40.1083332,inplace=True)

# %%
taxi_df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  50000.000000         50000.000000        50000.000000
# mean      11.364171           -72.509756           39.926539
# std        9.685557            10.393860            6.011669
# min       -5.000000           -75.423848          -74.006893
# 25%        6.000000           -73.992062           40.734879
# 50%        8.500000           -73.981840           40.752675
# 75%       12.500000           -73.967148           40.767359
# max      200.000000            40.783472           43.098708
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger  \
# count          50000.000000         50000.000000     50000.000000
# mean             -72.504616            39.926251         1.667840
# std               10.407570             6.014737         1.289195
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991152            40.734372         1.000000
# ...

# %%
pip install haversine

# %%
from haversine import haversine, Unit
taxi_df['travel_dist_km']=taxi_df.apply(lambda row: haversine((row["latitude_of_pickup"],row["longitude_of_pickup"]),(row["latitude_of_dropoff"],row["longitude_of_dropoff"]),unit=Unit.KILOMETERS),axis=1)

# %%
taxi_df.latitude_of_pickup.value_counts()
# Out:
# 0.000000     955
# 41.366138     18
# 40.756007     10
# 40.763975      8
# 40.757500      7
#             ...
# 40.725295      1
# 40.768578      1
# 40.740649      1
# 40.772588      1
# 40.768434      1
# Name: latitude_of_pickup, Length: 36594, dtype: int64

# %%
taxi_df.drop(taxi_df[taxi_df.longitude_of_pickup==0].index,inplace=True)

# %%
taxi_df.shape
# Out:
# (23226, 12)

# %%
taxi_df.drop(["longitude_of_pickup","latitude_of_pickup","longitude_of_dropoff","latitude_of_dropoff"],axis=1,inplace=True)

# %%
taxi_df.shape
# Out:
# (23226, 8)

# %%
X=taxi_df.values[:,1:]
Y=taxi_df.values[:,0]

# %%
taxi_df.describe()
# Out:
#              amount  no_of_passenger          hour           day  \
# count  23226.000000     23226.000000  23226.000000  23226.000000
# mean      11.465678         1.349823     13.425041     15.580556
# std        9.829508         0.811401      6.537510      8.656999
# min       -5.000000         0.000000      0.000000      1.000000
# 25%        6.000000         1.000000      9.000000      8.000000
# 50%        8.500000         1.000000     14.000000     16.000000
# 75%       12.900000         1.000000     19.000000     23.000000
# max      180.000000         6.000000     23.000000     31.000000
#
#               month          year     dayofweek  travel_dist_km
# count  23226.000000  23226.000000  23226.000000    23226.000000
# mean       6.073581   2011.926548      3.042108        9.627190
# std        3.429959      1.971276      1.955378      229.574525
# min        1.000000   2009.000000      0.000000        0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

scaler.fit(X)

X=scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split

#split the data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=10)

# %%
from sklearn.tree import DecisionTreeRegressor

model_DecisionTree = DecisionTreeRegressor(random_state=10)
model_DecisionTree.fit(X_train,Y_train)

Y_pred= model_DecisionTree.predict(X_test)

# %%
from sklearn .metrics import r2_score,mean_squared_error
import numpy as np

r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)

rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)

adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.5066166562762823
# RMSE: 7.237137450790216
# Adj R-square: 0.5064679060219078

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression

# first, initialize the classificators
tree= DecisionTreeRegressor(random_state=10) # using the random state for reproducibility
knn= KNeighborsRegressor(n_neighbors=5,metric='euclidean')
svm= SVR(kernel="rbf", gamma=0.1, C=1)
#logreg=LogisticRegression(multi_class="multinomial",random_state=10)

# %%
models=[tree,knn,svm]

# %%
from sklearn.metrics import confusion_matrix, r2_score,classification_report

# %%
for model in models:
    model.fit(X_train, Y_train) # fit the model
    Y_pred= model.predict(X_test) # then predict on the test set
    r2=r2_score(Y_test, Y_pred)
    #clf_report= classification_report(Y_test, Y_pred)
    #print(confusion_matrix(Y_test,Y_pred))
    print("The r2Score of the ",type(model).__name__, " model is ", r2*100 )
    #print("Classification report:\n", clf_report)
    print("\n")
# Out:
# The r2Score of the  DecisionTreeRegressor  model is  50.661665627628224
#
#
# The r2Score of the  KNeighborsRegressor  model is  -12.164722006083228
#
#
# The r2Score of the  SVR  model is  -3.325060138957414

# %%
from sklearn.svm import SVR

svr_model=SVR(kernel='rbf',C=90,gamma=0.1)
svr_model.fit(X_train,Y_train)
# Out:
# SVR(C=90, gamma=0.1)

# %%
from sklearn.metrics import r2_score

Y_pred_new=svr_model.predict(X_test)

#print(confusion_matrix(Y_test,Y_pred_new))
#print(classification_report(Y_test,Y_pred_new))
print(r2_score(Y_test,Y_pred_new))
# Out:
# 0.010603387526647468

# %%
#test=scaler.transform(testing_data)

# %%
from sklearn.tree import DecisionTreeRegressor
model_DecisionTree=DecisionTreeRegressor(criterion="squared_error",random_state=10)
model_DecisionTree.fit(X_train,Y_train)
Y_pred=model_DecisionTree.predict(X_test)
Y_pred
# Out:
# array([ 6.1,  3. ,  9.3, ..., 12.9,  8. ,  4.5])

# %%
print(r2_score(Y_test,Y_pred))
# Out:
# 0.5066166562762823

# %%
from sklearn.ensemble import ExtraTreesRegressor

model = ExtraTreesRegressor(n_estimators=100, random_state=10,bootstrap=True)

model.fit(X_train,Y_train)

Y_pred=model.predict(X_test)

# %%
print(r2_score(Y_test,Y_pred))
# Out:
# 0.6963584021855066

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100,random_state=10,bootstrap=True)
model.fit(X_train,Y_train)
Y_pred=model.predict(X_test)

# %%
print(r2_score(Y_test,Y_pred))
# Out:
# 0.7007118167270554

# %%
from sklearn.ensemble import AdaBoostRegressor

adaboost_model = AdaBoostRegressor(base_estimator=DecisionTreeRegressor(random_state=10),n_estimators=100,random_state=10)#n_estiamtors = no. of 100 DT/bags

adaboost_model.fit(X_train,Y_train)
Y_pred=adaboost_model.predict(X_test)

# %%
print(r2_score(Y_test,Y_pred))
# Out:
# 0.6804567000212737

# %%
from sklearn.ensemble import GradientBoostingRegressor
GradientBoosting_model = GradientBoostingRegressor(n_estimators=300,random_state=10)#n_estiamtors = no. of 100 DT/bags
GradientBoosting_model.fit(X_train,Y_train)
Y_pred=GradientBoosting_model.predict(X_test)

# %%
print(r2_score(Y_test,Y_pred))
# Out:
# 0.7231190993512375

# %%
from xgboost import XGBRegressor
XGB_model = XGBRegressor(n_estimators=100,random_state=10)
XGB_model.fit(X_train,Y_train)
Y_pred=XGB_model.predict(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import VotingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
# create the submodels
estimators=[]
#mode1-=LogoisticReegression()
model2 = DecisionTreeRegressor(criterion='squared_error',random_state=10)
estimators.append(('cart',model2))

model3=SVR(kernel="rbf",C=90,gamma=0.1)
estimators.append(('svm',model3))

model4=KNeighborsRegressor(n_neighbors=5,metric='euclidean')
estimators.append(('knn',model4))

# %%
# create ensemble model
ensemble =VotingRegressor(estimators)
ensemble.fit(X_train,Y_train)
Y_pred=ensemble.predict(X_test)
#pritnt(Y_pred)

# %%
print(r2_score(Y_test,Y_pred))
# Out:
# 0.5025457932104671

# %%
#from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import VotingRegressor, StackingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
#create sub models
estimators = []
#model1 = LogisticRegression()
#level0.append(('log', model1))

model2 = DecisionTreeRegressor(criterion='squared_error',random_state=10)
estimators.append(('cart', model2))

model3 = SVR(kernel='rbf',C=90,gamma=0.1)
estimators.append(('svm', model3))

model4 = KNeighborsRegressor(n_neighbors=5,metric='euclidean')
estimators.append(('knn',model4))

#level1=LogisticRegression()

# %%
# create ensemble model
ensemble = VotingRegressor(estimators)
ensemble.fit(X_train,Y_train)
Y_pred=ensemble.predict(X_test)
#print(Y_pred)

# %%
print(r2_score(Y_test,Y_pred))
# Out:
# 0.5025457932104671

# %%
#from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import VotingRegressor, StackingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
#create sub models
estimators = []

model2 = DecisionTreeRegressor(criterion='squared_error',random_state=10)
estimators.append(('cart', model2))

model3 = SVR(kernel='rbf',C=90,gamma=0.1)
estimators.append(('svm', model3))

model4 = KNeighborsRegressor(n_neighbors=5,metric='euclidean')
estimators.append(('knn',model4))

model12 = DecisionTreeRegressor()
